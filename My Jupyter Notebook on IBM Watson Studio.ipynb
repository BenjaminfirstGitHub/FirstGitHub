# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Li Chen__
#
# Current ocupation: Ph.D student in Engineering

# %% [markdown]
# *I am interested in data science because it is paid with high salary and I think it will be more popular in the future. In addition, learn skills about data science will increase the possibility to get a job in the future*

# %% [markdown]
# ### print "hello world"

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Table:
#
# title|title
# ---|---
# a|b
# c|d
#
# Hyperlinks:
#
# [This is a in-line link](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#links)
#
# [This is a reference link][1]
#
# [1]:https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#links
#
# Strikethrough: ~~~strikethrough~~~
